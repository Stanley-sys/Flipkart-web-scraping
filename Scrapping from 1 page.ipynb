# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import requests

# %%
url="https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles&requestId=ef1a2283-0b9e-4824-888b-6bcd70f60143"
headers={ 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36'}

# %%
response=requests.get(url,headers=headers)
page_soup=BeautifulSoup(response.content,features='html')

# %%
print(page_soup)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Scrap product name

# %%
product_class_name= "RG5Slk"
page_soup.find_all("div",{"class":"RG5Slk"})
# Out:
# [<div class="RG5Slk">Samsung Galaxy F07 (Green, 64 GB)</div>,
#  <div class="RG5Slk">MOTOROLA g06 power Charger in the Box (Pantone Tendril, 64 GB)</div>,
#  <div class="RG5Slk">IQOO Z11x 5G (Prismatic Green, 128 GB)</div>,
#  <div class="RG5Slk">realme P4 Lite (Beach Gold, 128 GB)</div>,
#  <div class="RG5Slk">REDMI A5 (Jaisalmer Gold, 64 GB)</div>,
#  <div class="RG5Slk">MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream, 128 GB)</div>,
#  <div class="RG5Slk">realme P4 Lite (Sea Blue, 128 GB)</div>,
#  <div class="RG5Slk">Ai+ Pulse 2 (Purple, 64 GB)</div>,
#  <div class="RG5Slk">Ai+ Pulse 2 (Blue, 64 GB)</div>,
#  <div class="RG5Slk">OPPO K14x 5G (Icy Blue, 64 GB)</div>,
#  <div class="RG5Slk">LAVA A3 King</div>,
#  <div class="RG5Slk">Ai+ Pulse 1 (Sparkle Red, 128 GB)</div>,
#  <div class="RG5Slk">Samsung M06 5G (Sage Green, 128 GB)</div>,
#  <div class="RG5Slk">realme P4x 5G (Matte Silver, 256 GB)</div>,
#  <div class="RG5Slk">Samsung Guru Music 2 B310ED</div>,
# ...

# %%
container=page_soup.find_all("div",{"class":"jIjQ8S"})

# %%
len(container)
# Out:
# 24

# %%
required_cols=["product_name","actual_price","sale_price","review & ratings","offer","camera","processor","memory","battery","display"]

# %%
product_name=container[0].find_all("div",{"class":"RG5Slk"})[0].text
product_name
# Out:
# 'Samsung Galaxy F07 (Green, 64 GB)'

# %%
review_and_rating=container[0].find_all("div",{"class":"a7saXW"})[0].text
review_and_rating
# Out:
# '4.36,115 Ratings\xa0&\xa0366 Reviews'

# %%
specification=container[0].find_all("div",{"class":"CMXw7N"})[0]
specification
# Out:
# <div class="CMXw7N"><ul class="HwRTzP"><li class="DTBslk">4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</li><li class="DTBslk">17.02 cm (6.7 inch) HD+ Display</li><li class="DTBslk">50MP + 2MP | 8MP Front Camera</li><li class="DTBslk">5000 mAh Battery</li><li class="DTBslk">Helio G99 Processor</li><li class="DTBslk">1 Year Manufacturer Warranty for Device and 6 Months for In-Box Accessories</li></ul></div>

# %%
specification.find_all('li')
# Out:
# [<li class="DTBslk">4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</li>,
#  <li class="DTBslk">17.02 cm (6.7 inch) HD+ Display</li>,
#  <li class="DTBslk">50MP + 2MP | 8MP Front Camera</li>,
#  <li class="DTBslk">5000 mAh Battery</li>,
#  <li class="DTBslk">Helio G99 Processor</li>,
#  <li class="DTBslk">1 Year Manufacturer Warranty for Device and 6 Months for In-Box Accessories</li>]

# %%
memory=specification.find_all('li')[0].text
memory
# Out:
# '4 GB RAM | 64 GB ROM | Expandable Upto 2 TB'

# %%
display=specification.find_all('li')[1].text
display
# Out:
# '17.02 cm (6.7 inch) HD+ Display'

# %%
camera=specification.find_all('li')[2].text
camera
# Out:
# '50MP + 2MP | 8MP Front Camera'

# %%
battery=specification.find_all('li')[3].text
battery
# Out:
# '5000 mAh Battery'

# %%
price=container[0].find_all("div",{"class":"oFEPlD"})[0].text
price
# Out:
# '₹9,999₹11,99916% off'

# %%
offer=container[0].find_all("div",{"class":"HQe8jr"})[0].text
offer
# Out:
# '16% off'

# %%
data={"Product Name":[],"Sale & Actual Price":[],"Review & Ratings":[],"Offer":[],"Camera":[],"Memory":[],"Battery":[],"Display":[],"Rating Number":[]}
for contain in container:
    pn=contain.find_all("div",{"class":"RG5Slk"})[0].text
    data["Product Name"].append(pn)
    
    rr=contain.find_all("div",{"class":"a7saXW"})
    if len(rr)==0:
        review_and_rating= None
        rating_number= None
    else:
        review_and_rating= rr[0].text
        rating_number= contain.find_all("div",{"class":"MKiFS6"})[0].text
    
    data["Review & Ratings"].append(review_and_rating)
    data["Rating Number"].append(rating_number)
    
    specification=contain.find_all("div",{"class":"CMXw7N"})[0]
    data["Memory"].append(specification.find_all('li')[0].text)
    data["Display"].append(specification.find_all('li')[1].text)
    data["Camera"].append(specification.find_all('li')[2].text)
    data["Battery"].append(specification.find_all('li')[3].text)
    
    price=contain.find_all("div",{"class":"oFEPlD"})[0].text
    data["Sale & Actual Price"].append(price)
    
    offer_list=contain.find_all("div",{"class":"HQe8jr"})
    if len(offer_list)==0:
        data["Offer"].append("No Offer")
    else:
        data["Offer"].append(offer_list[0].text)

# %%
data["Product Name"]
# Out:
# ['Samsung Galaxy F07 (Green, 64 GB)',
#  'MOTOROLA g06 power Charger in the Box (Pantone Tendril, 64 GB)',
#  'IQOO Z11x 5G (Prismatic Green, 128 GB)',
#  'realme P4 Lite (Beach Gold, 128 GB)',
#  'REDMI A5 (Jaisalmer Gold, 64 GB)',
#  'MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream, 128 GB)',
#  'realme P4 Lite (Sea Blue, 128 GB)',
#  'Ai+ Pulse 2 (Purple, 64 GB)',
#  'Ai+ Pulse 2 (Blue, 64 GB)',
#  'OPPO K14x 5G (Icy Blue, 64 GB)',
#  'LAVA A3 King',
#  'Ai+ Pulse 1 (Sparkle Red, 128 GB)',
#  'Samsung M06 5G (Sage Green, 128 GB)',
#  'realme P4x 5G (Matte Silver, 256 GB)',
#  'Samsung Guru Music 2 B310ED',
#  'OPPO K14x 5G (Prism Violet, 64 GB)',
#  'itel it5262',
#  'Samsung M06 5G (Sage Green, 128 GB)',
#  'Samsung Galaxy F70e 5G (Limelight Green, 128 GB)',
#  'IQOO 15R 5G (Triumph Silver, 256 GB)',
#  'POCO M7 Plus 5G (Carbon Black, 128 GB)',
#  'Samsung Galaxy F70e 5G (Limelight Green, 128 GB)',
#  'Samsung M06 5G (Blazing Black, 128 GB)',
# ...

# %%
pd.DataFrame(data)
# Out:
#                                          Product Name    Sale & Actual Price  \
# 0                   Samsung Galaxy F07 (Green, 64 GB)   ₹9,999₹11,99916% off
# 1   MOTOROLA g06 power Charger in the Box (Pantone...   ₹12,999₹13,9997% off
# 2              IQOO Z11x 5G (Prismatic Green, 128 GB)  ₹21,785₹28,99924% off
# 3                 realme P4 Lite (Beach Gold, 128 GB)   ₹12,999₹13,9997% off
# 4                    REDMI A5 (Jaisalmer Gold, 64 GB)                 ₹8,999
# 5   MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...   ₹22,999₹24,9998% off
# 6                   realme P4 Lite (Sea Blue, 128 GB)   ₹12,999₹13,9997% off
# 7                         Ai+ Pulse 2 (Purple, 64 GB)    ₹9,999₹10,9999% off
# 8                           Ai+ Pulse 2 (Blue, 64 GB)    ₹9,999₹10,9999% off
# 9                      OPPO K14x 5G (Icy Blue, 64 GB)  ₹14,999₹19,99925% off
# 10                                       LAVA A3 King    ₹1,231₹1,54920% off
# ...
